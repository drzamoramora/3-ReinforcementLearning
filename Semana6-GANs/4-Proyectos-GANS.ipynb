# %% [markdown]
# ## Miles de GANS
#
# Hay miles de artículos sobre GAN y muchos cientos de GAN con nombre, es decir, modelos con un nombre definido que a menudo incluye "GAN", como DCGAN, en lugar de una extensión menor del método. Dado el gran tamaño de la literatura GAN y la cantidad de modelos, puede ser, como mínimo, confuso y frustrante saber en qué modelos GAN enfocarse.
#
# Podemos clasificar las GANs de la siguiente forma:
#
# Basico
# - Generative Adversarial Network (GAN)
# - Deep Convolutional Generative Adversarial Network (DCGAN)
#
# Extensiones
# - Conditional Generative Adversarial Network (cGAN)
# - Information Maximizing Generative Adversarial Network (InfoGAN)
# - Auxiliary Classifier Generative Adversarial Network (AC-GAN)
# - Stacked Generative Adversarial Network (StackGAN)
# - Context Encoders
# - Pix2Pix
#
# Avanzadas
# - Wasserstein Generative Adversarial Network (WGAN)
# - Cycle-Consistent Generative Adversarial Network (CycleGAN)
# - Progressive Growing Generative Adversarial Network (Progressive GAN)
# - Style-Based Generative Adversarial Network (StyleGAN)
# - Big Generative Adversarial Network (BigGAN)
#
# ### Papers
#
# Basico
# <ul>
# <li><a href="https://arxiv.org/abs/1406.2661">Generative Adversarial Networks</a>, 2014.</li>
# <li><a href="https://arxiv.org/abs/1511.06434">Unsupervised Representation Learning with Deep Convolutional Generative Adversarial Networks</a>, 2015.</li>
# </ul>
#
# Extensiones
# <ul>
# <li><a href="https://arxiv.org/abs/1411.1784">Conditional Generative Adversarial Nets</a>, 2014.</li>
# <li><a href="https://arxiv.org/abs/1606.03657">InfoGAN: Interpretable Representation Learning by Information Maximizing Generative Adversarial Nets</a>, 2016.</li>
# <li><a href="https://arxiv.org/abs/1610.09585">Conditional Image Synthesis With Auxiliary Classifier GANs</a>, 2016.</li>
# <li><a href="https://arxiv.org/abs/1612.03242">StackGAN: Text to Photo-realistic Image Synthesis with Stacked Generative Adversarial Networks</a>, 2016.</li>
# <li><a href="https://arxiv.org/abs/1604.07379">Context Encoders: Feature Learning by Inpainting</a>, 2016.</li>
# <li><a href="https://arxiv.org/abs/1611.07004">Image-to-Image Translation with Conditional Adversarial Networks</a>, 2016.</li>
# </ul>
#
# Avanzado
# <ul>
# <li><a href="https://arxiv.org/abs/1701.07875">Wasserstein GAN</a>, 2017.</li>
# <li><a href="https://arxiv.org/abs/1703.10593">Unpaired Image-to-Image Translation using Cycle-Consistent Adversarial Networks</a>, 2017.</li>
# <li><a href="https://arxiv.org/abs/1710.10196">Progressive Growing of GANs for Improved Quality, Stability, and Variation</a>, 2017.</li>
# <li><a href="https://arxiv.org/abs/1812.04948">A Style-Based Generator Architecture for Generative Adversarial Networks</a>, 2018.</li>
# <li><a href="https://arxiv.org/abs/1809.11096">Large Scale GAN Training for High Fidelity Natural Image Synthesis</a>, 2018.</li>
# </ul>
#
# Articulos
# <ul>
# <li><a href="https://github.com/eriklindernoren/Keras-GAN">Keras-GAN: Keras implementations of Generative Adversarial Networks</a>.</li>
# <li><a href="https://github.com/hindupuravinash/the-gan-zoo">the-gan-zoo: A list of all named GANs!</a></li>
# </ul>
#
# ### Algunas Recomendas por el Profe para Empezar (Tensorflow):
#
# <ul>
# <li><a href="https://github.com/NVlabs/stylegan">StyleGan - Implementacion de NVidia</a>.</li>
#     <li><a href="https://github.com/NVlabs/stylegan2">StyleGan2 - Implementacion de NVidia</a>.</li>
# <li><a href="https://www.tensorflow.org/hub/tutorials/biggan_generation_with_tf_hub">BigGan - de Google</a></li>
# </ul>
