# %% [markdown]
# # Tarea
#
# ## Dataset: Correos de Enron
#
# Enron fue una empresa petrolera norteamericana que quebró estrepitosamente en el año 2001 luego de haber hecho lo que fue hasta su momento el fraude contable más grande de la historia. Como parte de la investigación criminal, se analizaron cientos de miles de mensajes de los servidores de correo electrónico de la compañía.
#
# El dataset está disponible para el público desde hace varios años. Aquí tenemos una muestra preprocesada con aproximadamente 10,000 mensajes de correo electrónico listos para ser analizados.

# %%
# Importamos bibliotecas necesarias para la tarea
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation
from hmmlearn import hmm
from sklearn.preprocessing import LabelEncoder
import numpy as np

# Leemos el dataset
enron_file = open('resources/enron.csv', 'r') 
enron = enron_file.readlines()
enron = [ l.rstrip() for l in enron ]

# %%
### EJERCICIO 1 (1 punto)
### - CONSTRUIR UN VECTORIZADOR DE CONTEOS QUE ELIMINE STOP-WORDS EN INGLÉS PARA EL DATASET enron
### - UTILIZARLO PARA TRANSFORMAR EL DATASET EN UNA MATRIZ DOCUMENTO-PALABA
cv = CountVectorizer(stop_words='english', token_pattern=r"(?u)\b[a-zA-Z][a-zA-Z][a-zA-Z]+\b").fit(enron)
enron_matrix = cv.transform(enron)

# %%
### EJERCICIO 2 (4 puntos)
### - ENTRENAR UN MODELO DE ASIGNACION LATENTE DE DIRICHLET SOBRE enron_matrix.
### - MOSTRAR LOS TÓPICOS RESULTANTES (las 30 palabras más relevantes por tópico)
### - PROBAR CON DISTINTOS NÚMEROS DE TÓPICOS, REPORTAR SUS RESULTADOS. 
lda = LatentDirichletAllocation(n_components=5, verbose=True).fit(enron_matrix)

comp = lda.components_
vec = np.array(cv.get_feature_names())
for i in range(0, comp.shape[0]):
    print('*** TOPICO ', i)
    print(vec[comp[i].argsort()[-30:][::-1]])
    print('\n')
# Out:
# iteration: 1 of max_iter: 10
# iteration: 2 of max_iter: 10
# iteration: 3 of max_iter: 10
# iteration: 4 of max_iter: 10
# iteration: 5 of max_iter: 10
# iteration: 6 of max_iter: 10
# iteration: 7 of max_iter: 10
# iteration: 8 of max_iter: 10
# iteration: 9 of max_iter: 10
# iteration: 10 of max_iter: 10
# *** TOPICO  0
# ['enron' 'image' 'said' 'power' 'market' 'gas' 'new' 'energy' 'company'
#  'business' 'year' 'prices' 'houston' 'price' 'iso' 'trading' 'state'
#  'california' 'markets' 'million' 'enrons' 'jones' 'service' 'credit'
#  'financial' 'president' 'time' 'deal' 'natural' 'dow']
#
#
# *** TOPICO  1
# ['john' 'subject' 'message' 'sent' 'original' 'thanks' 'arnold' 'phillip'
#  'gas' 'enron' 'monday' 'october' 'arnoldhouectect' 'tuesday' 'allen'
#  'need' 'trading' 'time' 'day' 'november' 'know' 'today' 'value' 'mike'
#  'kim' 'information' 'wednesday' 'market' 'thank' 'attached']
#
#
# *** TOPICO  2
# ['subject' 'eric' 'know' 'basshouectect' 'let' 'enron' 'going' 'just'
#  'think' 'dont' 'need' 'want' 'mail' 'like' 'john' 'thanks' 'time' 'bass'
#  'game' 'phillip' 'brian' 'good' 'work' 'tonight' 'north' 'make' 'bryan'
#  'jennifer' 'america' 'corp']
#
#
# *** TOPICO  3
# ['week' 'play' 'buy' 'sore' 'start' 'expected' 'like' 'game' 'sunday'
#  'hes' 'good' 'team' 'questionable' 'practice' 'smith' 'offset' 'looks'
#  'moving' 'just' 'likely' 'saturday' 'downgraded' 'look' 'injury' 'yards'
#  'johnson' 'players' 'update' 'knee' 'report']
#
#
# *** TOPICO  4
# ['texas' 'time' 'team' 'brown' 'meeting' 'like' 'year' 'project' 'wine'
#  'game' 'new' 'enron' 'information' 'market' 'bowl' 'need' 'think'
#  'questions' 'said' 'season' 'know' 'services' 'order' 'iso' 'week' 'look'
#  'state' 'december' 'management' 'august']

# %%
### EJERCICIO 3 (1 punto)
### - CONSTRUIR UN LabelEncoder CON LOS DATOS DE enron Y TRANSFORMAR LOS DATOS
###   EL LabelEncoder DEBE SEPARAR LOS MENSAJES PALABRA POR PALABRA
### - TRANSFORMAR EN DATASETS CODIFICADOS
### - CREAR EL VECTOR DE LONGITUD DE MENSAJES
###
### *** IMPORTANTE: DADO EL TIEMPO EXCESIVO QUE TOMA ENTRENAR ESTE MODELO, 
###     SE RECOMIENDA TRABAJAR CON UNA MUESTRA REDUCIDA (p.ej. LOS PRIMEROS 100 MENSAJES)


enron_chars = [ mail.lower().split(' ') for mail in enron[-200:] ]
chars_len = [ len(chars) for chars in enron_chars ]
cv_chars = LabelEncoder().fit([y for l in enron_chars for y in l])
chars_enc = np.concatenate([cv_chars.transform(y).reshape(-1, 1) for y in enron_chars]).astype(np.int64)

# %%
### EJERCICIO 4 (4 puntos)
### - ENTRENAR UN MODELO OCULTO DE MARKOV (HMM) SOBRE chars_enc Y chars_len
### - GENERAR DIEZ SECUENCIAS ALEATORIAS DE DISTINTAS LONGITUDES
### - PROBAR CON DISTINTOS NÚMEROS DE COMPONENTES, REPORTAR SUS RESULTADOS. 

enron_model = hmm.MultinomialHMM(n_iter=100, n_components=10, verbose=True).fit(chars_enc, chars_len)
# Out:
# Fitting a model with 82989 free scalar parameters with only 61870 data points will result in a degenerate solution.
#          1     -558861.6911             +nan
#          2     -441041.0291     +117820.6619
#          3     -441038.4537          +2.5754
#          4     -441034.5470          +3.9067
#          5     -441028.1843          +6.3628
#          6     -441017.8332         +10.3511
#          7     -441002.0202         +15.8130
#          8     -440980.7233         +21.2969
#          9     -440955.3655         +25.3578
#         10     -440927.2041         +28.1614
#         11     -440897.2964         +29.9077
#         12     -440866.4604         +30.8360
#         13     -440834.6334         +31.8271
#         14     -440800.7390         +33.8944
#         15     -440762.8720         +37.8670
#         16     -440718.3247         +44.5473
#         17     -440663.3773         +54.9473
#         18     -440592.9744         +70.4029
#         19     -440500.0328         +92.9416
#         20     -440373.2210        +126.8118
#         21     -440193.1154        +180.1056
#         22     -439926.6053        +266.5101
#         23     -439518.3708        +408.2345
#         24     -438880.8929        +637.4779
#         25     -437892.1700        +988.7229
#         26     -436421.2526       +1470.9175
#         27     -434394.0248       +2027.2277
#         28     -431860.6815       +2533.3433
#         29     -428961.2413       +2899.4402
#         30     -425842.2090       +3119.0323
#         31     -422659.8155       +3182.3935
#         32     -419587.9409       +3071.8746
#         33     -416751.6284       +2836.3125
#         34     -414204.9185       +2546.7099
#         35     -411964.7806       +2240.1379
#         36     -410046.5457       +1918.2349
#         37     -408459.4582       +1587.0875
#         38     -407177.3176       +1282.1407
#         39     -406185.7504        +991.5672
#         40     -405435.7323        +750.0181
#         41     -404845.0406        +590.6917
#         42     -404342.5875        +502.4530
#         43     -403898.1693        +444.4182
#         44     -403513.8516        +384.3177
#         45     -403205.5189        +308.3327
#         46     -402956.4844        +249.0345
#         47     -402748.7778        +207.7066
#         48     -402555.9555        +192.8223
#         49     -402373.3012        +182.6542
#         50     -402214.5260        +158.7752
#         51     -402067.7678        +146.7581
#         52     -401923.1392        +144.6287
#         53     -401774.4542        +148.6850
#         54     -401638.4472        +136.0070
#         55     -401513.1810        +125.2662
#         56     -401397.7352        +115.4457
#         57     -401291.0250        +106.7103
#         58     -401184.1950        +106.8300
#         59     -401086.6150         +97.5800
#         60     -401000.8840         +85.7310
#         61     -400915.3804         +85.5036
#         62     -400814.4487        +100.9317
#         63     -400725.1464         +89.3024
#         64     -400637.6432         +87.5032
#         65     -400541.7818         +95.8614
#         66     -400448.4789         +93.3029
#         67     -400361.0348         +87.4440
#         68     -400272.4979         +88.5369
#         69     -400185.2420         +87.2558
#         70     -400101.7955         +83.4465
#         71     -400009.7260         +92.0695
#         72     -399928.4388         +81.2872
#         73     -399863.1772         +65.2616
#         74     -399803.8855         +59.2917
#         75     -399740.8344         +63.0511
#         76     -399673.2116         +67.6228
#         77     -399603.0324         +70.1792
#         78     -399541.5105         +61.5219
#         79     -399489.0091         +52.5013
#         80     -399446.6216         +42.3875
#         81     -399401.7336         +44.8881
#         82     -399345.1931         +56.5405
#         83     -399283.4407         +61.7523
#         84     -399223.0295         +60.4112
#         85     -399169.4754         +53.5541
#         86     -399115.6969         +53.7786
#         87     -399060.7803         +54.9166
#         88     -399007.7165         +53.0638
#         89     -398953.4439         +54.2725
#         90     -398903.3241         +50.1198
#         91     -398859.0772         +44.2469
#         92     -398813.3475         +45.7297
#         93     -398774.0025         +39.3450
#         94     -398738.1207         +35.8818
#         95     -398702.2003         +35.9204
#         96     -398672.4110         +29.7893
#         97     -398642.1863         +30.2247
#         98     -398609.3947         +32.7916
#         99     -398572.8670         +36.5277
#        100     -398537.0204         +35.8466

# %%
print(' '.join(cv_chars.inverse_transform(enron_model.sample(10)[0])))
# Out:
# lindsaymearthlinknet shanna havent 0357 rotation will nebraska out how outside
